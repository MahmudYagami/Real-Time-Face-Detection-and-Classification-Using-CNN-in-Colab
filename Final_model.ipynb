# %%
from google.colab import drive
import os
import cv2

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
original_dataset_path = "give your dataset path"
preprocessed_path = "give your path to save face_detection_preprocessed_2 file"

if not os.path.exists(preprocessed_path):
    os.makedirs(preprocessed_path)

print("Original Folders in Dataset:", os.listdir(original_dataset_path))
# Out:
# Original Folders in Dataset: ['Shoily', 'Munni', 'Akid', 'Rafsan']

# %%
haar_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

print("Original Folders in Dataset:", os.listdir(original_dataset_path))

for folder in os.listdir(original_dataset_path):
    folder_path = os.path.join(original_dataset_path, folder)
    save_folder = os.path.join(preprocessed_path, folder)

    if not os.path.exists(save_folder):
        os.makedirs(save_folder)

    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        img = cv2.imread(img_path)

        if img is not None:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            faces = haar_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

            if len(faces) == 0:
                print(f"No faces detected in {img_name}")


            for (x, y, w, h) in faces:
                face = gray[y:y + h, x:x + w]
                face_resized = cv2.resize(face, (224, 224))
                save_path = os.path.join(save_folder, img_name)
                cv2.imwrite(save_path, face_resized)

                print(f"Saved {img_name} in {save_folder}")
        else:
            print(f"Failed to read image {img_name}")

print("Preprocessed Folders in Dataset:", os.listdir(preprocessed_path))
# Out:
# Original Folders in Dataset: ['Shoily', 'Munni', 'Akid', 'Rafsan']
# Saved frame_0982.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0972.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0976.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0975.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0968.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0990.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_1000.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0977.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0971.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0979.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_1011.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0967.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0989.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_1023.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0973.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0994.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0995.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0986.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0974.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0992.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0983.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0978.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0988.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0980.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0987.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0985.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0985.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_1014.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0997.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0981.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_1003.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0933.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0959.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0922.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0957.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0949.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0970.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0984.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0960.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0932.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0932.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0934.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0965.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0945.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0925.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0954.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0962.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0944.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0950.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0969.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0943.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0958.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0928.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0942.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0966.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0966.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0964.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0953.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0939.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0961.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0940.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0935.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0963.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0956.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0937.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0951.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0941.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0946.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0952.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0920.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0902.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0921.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0904.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0914.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0927.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0905.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0948.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0936.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0898.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0895.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0915.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0907.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0923.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0899.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0903.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0896.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0924.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0924.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0917.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0912.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0947.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0909.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0918.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0916.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0926.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0931.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0931.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0897.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0897.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0913.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0919.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0929.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0893.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0893.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0908.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0906.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0930.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0911.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0866.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0877.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0887.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0868.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0894.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0869.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0890.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0883.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0871.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0879.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0938.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0888.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0891.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0872.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0892.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0892.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0875.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0864.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0880.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0910.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0900.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0878.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0867.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0870.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0881.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0901.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0882.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0955.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0863.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0876.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0889.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0885.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0886.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0861.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0884.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0874.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0860.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0832.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0858.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0855.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0853.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0853.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0843.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0831.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0838.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0840.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0834.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0850.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0850.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0865.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0854.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0854.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0851.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0841.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0846.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0842.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0848.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0848.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0829.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0837.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0862.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0849.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0849.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0844.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0836.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0847.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0847.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0852.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0833.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0859.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0845.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0830.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0830.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0830.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0873.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0857.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0857.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0856.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0856.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0839.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0839.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0835.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0797.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0809.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0810.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0815.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0828.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0794.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0807.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0813.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0793.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0799.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0802.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0827.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0827.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0822.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0814.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0816.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0821.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0812.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0826.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0826.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0817.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0801.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0824.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0824.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0808.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_0798.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Shoily
# Saved frame_
jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0063.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0077.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0074.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0064.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0057.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0072.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0052.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0073.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0067.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0065.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0068.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0050.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0066.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0056.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0053.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0055.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0071.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0069.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0054.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1049.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1036.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1031.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1040.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1039.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1034.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1043.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1038.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1048.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1041.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1033.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1047.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1042.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1037.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1046.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1044.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1026.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1026.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1030.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1032.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1007.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1025.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1015.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0987.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0995.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0995.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0991.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1027.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1027.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0996.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0996.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0994.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0994.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1018.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1018.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1005.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1011.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1019.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1019.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0978.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1022.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1001.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1001.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1001.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1017.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1017.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1023.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1016.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1016.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1021.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0972.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1045.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1004.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1012.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1029.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1006.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0989.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1024.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0999.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_0999.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1008.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1010.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Saved frame_1010.jpg in /content/drive/My Drive/FACE DETECTION/face_detection_preprocessed_2/Rafsan
# Preprocessed Folders in Dataset: ['Shoily', 'Munni', 'Akid', 'Rafsan']

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import optimizers


img_height, img_width = 224, 224
batch_size = 64
learning_rate = 0.0001


datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    preprocessed_path,
    target_size=(img_height, img_width),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

val_data = datagen.flow_from_directory(
    preprocessed_path,
    target_size=(img_height, img_width),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=True
)

model = Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(img_height, img_width, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(32, (3, 3), activation='relu'),  # Second Conv Layer
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),  # Third Conv Layer
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.4),
    Dense(len(train_data.class_indices), activation='softmax')
])


model.compile(
    optimizer=optimizers.Adam(learning_rate=learning_rate),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ModelCheckpoint('best_model.keras', save_best_only=True)
]

# Train the Model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=20,
    callbacks=callbacks
)
# Out:
# Found 3066 images belonging to 4 classes.
# Found 765 images belonging to 4 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 28s 409ms/step - accuracy: 0.3446 - loss: 1.3000 - val_accuracy: 0.7660 - val_loss: 1.0555
# Epoch 2/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 248ms/step - accuracy: 0.6113 - loss: 0.9441 - val_accuracy: 0.7529 - val_loss: 0.6288
# Epoch 3/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 14s 251ms/step - accuracy: 0.7756 - loss: 0.6084 - val_accuracy: 0.9569 - val_loss: 0.3685
# Epoch 4/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 247ms/step - accuracy: 0.8704 - loss: 0.4260 - val_accuracy: 0.9621 - val_loss: 0.2529
# Epoch 5/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 249ms/step - accuracy: 0.9035 - loss: 0.3110 - val_accuracy: 0.9582 - val_loss: 0.1825
# Epoch 6/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 249ms/step - accuracy: 0.9354 - loss: 0.2322 - val_accuracy: 0.9608 - val_loss: 0.1590
# Epoch 7/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 245ms/step - accuracy: 0.9391 - loss: 0.1909 - val_accuracy: 0.9529 - val_loss: 0.1632
# Epoch 8/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 250ms/step - accuracy: 0.9464 - loss: 0.1733 - val_accuracy: 0.9608 - val_loss: 0.1593
# Epoch 9/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 248ms/step - accuracy: 0.9440 - loss: 0.1756 - val_accuracy: 0.9516 - val_loss: 0.1653
# Epoch 10/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 253ms/step - accuracy: 0.9399 - loss: 0.1855 - val_accuracy: 0.9582 - val_loss: 0.1754
# Epoch 11/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 246ms/step - accuracy: 0.9393 - loss: 0.1844 - val_accuracy: 0.9647 - val_loss: 0.1684
# Epoch 12/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 247ms/step - accuracy: 0.9280 - loss: 0.1832 - val_accuracy: 0.9634 - val_loss: 0.1606
# Epoch 13/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 246ms/step - accuracy: 0.9453 - loss: 0.1617 - val_accuracy: 0.9621 - val_loss: 0.1849
# Epoch 14/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 249ms/step - accuracy: 0.9323 - loss: 0.1736 - val_accuracy: 0.9608 - val_loss: 0.1437
# Epoch 15/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 289ms/step - accuracy: 0.9403 - loss: 0.1514 - val_accuracy: 0.9686 - val_loss: 0.1510
# Epoch 16/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 243ms/step - accuracy: 0.9512 - loss: 0.1430 - val_accuracy: 0.9621 - val_loss: 0.1624
# Epoch 17/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 247ms/step - accuracy: 0.9601 - loss: 0.1437 - val_accuracy: 0.9752 - val_loss: 0.1487
# Epoch 18/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 249ms/step - accuracy: 0.9611 - loss: 0.1185 - val_accuracy: 0.9660 - val_loss: 0.1497
# Epoch 19/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 243ms/step - accuracy: 0.9553 - loss: 0.1494 - val_accuracy: 0.9634 - val_loss: 0.1583
# Epoch 20/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 241ms/step - accuracy: 0.9464 - loss: 0.1290 - val_accuracy: 0.9699 - val_loss: 0.1506

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 16)        │             160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 109, 109, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 54, 54, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 52, 52, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 26, 26, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 43264)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │       2,768,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │             260 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,377,550 (31.96 MB)
#  Trainable params: 2,792,516 (10.65 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 5,585,034 (21.31 MB)

# %%
plt.figure(figsize=(10, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'], marker='o', label='Train Accuracy')
plt.plot(history.history['val_accuracy'], marker='o', label='Validation Accuracy')
plt.xticks(np.arange(1, len(history.history['accuracy']) + 1, 1))
plt.xlim(1, len(history.history['accuracy']))
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(loc='best')
plt.show()

# Plot training & validation loss
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], marker='x', label='Train Loss')
plt.plot(history.history['val_loss'], marker='x', label='Validation Loss')
plt.xticks(np.arange(1, len(history.history['loss']) + 1, 1))
plt.xlim(1, len(history.history['loss']))
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(loc='best')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


val_loss, val_acc = model.evaluate(val_data, verbose=1)


print(f"\nValidation Accuracy: {val_acc * 100:.2f}%")
print(f"Validation Loss: {val_loss:.4f}")


X_test, Y_test = next(val_data)
predictions = model.predict(X_test)


class_names = list(val_data.class_indices.keys())

rows, cols = 5, 5
plt.figure(figsize=(20, 10))

for i in range(rows * cols):
    if i >= len(X_test):
        break


    plt.subplot(rows, 2 * cols, 2 * i + 1)
    img = X_test[i].squeeze() * 255
    img = np.clip(img, 0, 255).astype('uint8')
    plt.imshow(img, cmap='gray')
    plt.xticks([])
    plt.yticks([])

    true_label = np.argmax(Y_test[i])
    pred_label = np.argmax(predictions[i])
    plt.ylabel(f"True: {class_names[true_label]}")

    if true_label == pred_label:
        plt.xlabel(f"Pred: {class_names[pred_label]}", color='g')
    else:
        plt.xlabel(f"Pred: {class_names[pred_label]}", color='r')

    plt.subplot(rows, 2 * cols, 2 * i + 2)
    plt.bar(range(len(class_names)), predictions[i])
    plt.xticks(range(len(class_names)), class_names, rotation=90)
    plt.yticks([])
    plt.ylim([0, 1])
    plt.title("Confidences")

plt.tight_layout()
plt.show()

# %%
model.save('path to save the model in Final_Model.keras')

model.save('path to save the model in Final_Model.h5', save_format='h5')

print("Model saved successfully!")
# Out:
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!
